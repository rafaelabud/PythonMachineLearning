# %%
import seaborn as sns
import pandas as pd

# %%
df = pd.read_csv('carros.csv')

# %%
sns.countplot(df['doors'])

# %%
sns.countplot(df['riskiness'])

# %%
sns.countplot(df['body'])

# %%
sns.countplot(df['doors'], hue=df['riskiness'])

# %%
sns.countplot(df['doors'], hue=df['body'])

# %%
sns.countplot(df['doors'], hue=df['aspiration'])
