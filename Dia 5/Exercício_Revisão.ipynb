# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
iris[4]
lista_flores
# Out:
# ['Iris-setosa', 'Iris-versicolor', 'Iris-virginica']

# %%
def muda(valor):
    if valor==lista_flores[0]:
        return 0
    if valor==lista_flores[1]:
        return 1
    if valor==lista_flores[2]:
        return 2
    
iris = pd.read_csv('iris.data', header=None)
lista_flores = iris[4].unique().tolist()
iris[4] = iris[4].apply(muda)

# %%
#Questão 2
df[4].value_counts().plot(kind='bar')
sns.countplot(df[4])

# %%
X = iris[[0,1,2,3]]
y = iris[4]
X.columns = ['Petal length','Petal width','Sepal length','Sepal width']
y = pd.DataFrame(y)
y.columns = ['target']
df = pd.concat([X,y], axis = 1)

# %%
g = sns.boxplot(y='Petal length', x='target', data=df)
g.set_xticklabels(g.get_xticklabels(),rotation=90)
plt.show()
g = sns.boxplot(y='Petal width', x='target', data=df)
g.set_xticklabels(g.get_xticklabels(),rotation=90)
plt.show()
g = sns.boxplot(y='Sepal length', x='target', data=df)
g.set_xticklabels(g.get_xticklabels(),rotation=90)
plt.show()
g = sns.boxplot(y='Sepal width', x='target', data=df)
g.set_xticklabels(g.get_xticklabels(),rotation=90)
plt.show()

# %%
df
# Out:
#      Petal length  Petal width  Sepal length  Sepal width  target
# 0             5.1          3.5           1.4          0.2       0
# 1             4.9          3.0           1.4          0.2       0
# 2             4.7          3.2           1.3          0.2       0
# 3             4.6          3.1           1.5          0.2       0
# 4             5.0          3.6           1.4          0.2       0
# 5             5.4          3.9           1.7          0.4       0
# 6             4.6          3.4           1.4          0.3       0
# 7             5.0          3.4           1.5          0.2       0
# 8             4.4          2.9           1.4          0.2       0
# 9             4.9          3.1           1.5          0.1       0
# 10            5.4          3.7           1.5          0.2       0
# 11            4.8          3.4           1.6          0.2       0
# 12            4.8          3.0           1.4          0.1       0
# ...

# %%
plt.scatter(df['Petal length'],df['Petal width'], c=df['target'])
#plt.title("title")
plt.xlabel("Petal length")
plt.ylabel("Petal width")
plt.axhline(y=3, label = 'Valor médio',color='blue', linestyle='--')
plt.show()

# %%
plt.scatter(df['Sepal length'],df['Sepal width'], c=df['target'])
#plt.title("title")
plt.xlabel("Sepal length")
plt.ylabel("Sepal width")
plt.axhline(y=0.75, label = 'Valor médio',color='blue', linestyle='--')
plt.show()

# %%
df[df['Sepal width']<=0.75]['target'].value_counts()
# Out:
# 0    50
# Name: target, dtype: int64
