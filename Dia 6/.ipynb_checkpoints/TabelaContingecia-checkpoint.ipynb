# %%
import pandas as pd

# %%
carros = pd.read_csv('carros.csv')
carros
# Out:
#      riskiness  losses        make fuel type  city mpg  highway mpg  \
# 0            2   164.0        audi       gas      24.0         30.0
# 1            2   164.0        audi       gas      18.0         22.0
# 2            1   158.0        audi       gas      19.0         25.0
# 3            1   158.0        audi       gas      17.0         20.0
# 4            2   192.0         bmw       gas      23.0         29.0
# 5            0     NaN         bmw       gas      23.0         29.0
# 6            0   188.0         bmw       gas      21.0         28.0
# 7            0   188.0         bmw       gas      21.0         28.0
# 8            2   121.0   chevrolet       gas      47.0         53.0
# 9            1    98.0   chevrolet       gas      38.0         43.0
# 10           0    81.0   chevrolet       gas      38.0         43.0
# 11           1     NaN       dodge       gas      37.0         41.0
# 12           1   118.0       dodge       gas      31.0         38.0
# ...

# %%
#Tabela de contingência
pd.crosstab(carros['body'],carros['doors'])

# %%
#Dois atributos numéricos 
        #- Coeficiente de pearson ou spearman 
        #- gráfico de dispersão 
#1 numérico 1 catgórico
        #- boxplot
#3 Dois categóricos
        #-Tabela de contingência
# Out:
# doors        four  two
# body
# convertible     0    2
# hardtop         0    5
# hatchback      10   47
# sedan          71   13
# wagon          17    0
