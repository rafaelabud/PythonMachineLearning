# %%
# Load libraries
from sklearn.ensemble import AdaBoostClassifier
from sklearn import datasets
# Import train_test_split function
from sklearn.model_selection import train_test_split
#Import scikit-learn metrics module for accuracy calculation
from sklearn import metrics

# %%
# Load data
iris = datasets.load_iris()
X = iris.data
y = iris.target
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3) # 70% training and 30% test

# %%
# Create adaboost classifer object
abc = AdaBoostClassifier(n_estimators=50,learning_rate=1)
# Train Adaboost Classifer
model = abc.fit(X_train, y_train)

#Predict the response for test dataset
y_pred = model.predict(X_test)

# %%
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9333333333333333

# %%
from sklearn.ensemble import AdaBoostClassifier

# Import Support Vector Classifier
from sklearn.svm import SVC
#Import scikit-learn metrics module for accuracy calculation
from sklearn import metrics
svc=SVC(probability=True, kernel='linear')

# Create adaboost classifer object
abc =AdaBoostClassifier(n_estimators=50, base_estimator=svc,learning_rate=1)

# Train Adaboost Classifer
model = abc.fit(X_train, y_train)

#Predict the response for test dataset
y_pred = model.predict(X_test)


# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-fc816a071c66> in <module>()
#      11
#      12 # Train Adaboost Classifer
# ---> 13 model = abc.fit(X_train, y_train)
#      14
#      15 #Predict the response for test dataset
#
# NameError: name 'X_train' is not defined

# %%
import pandas as pd
df_dor = pd.DataFrame(['Sim','Não','Sim','Sim','Não','Não','Sim','Sim'])
df_arteria = pd.DataFrame(['Sim','Sim','Não','Sim','Sim','Sim','Não','Sim'])
df_peso = pd.DataFrame([205,180,210,167,156,125,168,172])
df_resposta = pd.DataFrame(['Sim','Sim','Sim','Sim','Não','Não','Não','Não'])
df_pesos = pd.DataFrame([0.07,0.07,0.07,0.49,0.07,0.07,0.07,0.07])
df = pd.concat([df_dor, df_arteria, df_peso, df_resposta, df_pesos], axis = 1)
df.columns = ['Dor no peito','Artérias bloqueadas','Peso do paciente','Doença cardiaca','Pesos']
df
# Out:
#   Dor no peito Artérias bloqueadas  Peso do paciente Doença cardiaca  Pesos
# 0          Sim                 Sim               205             Sim   0.07
# 1          Não                 Sim               180             Sim   0.07
# 2          Sim                 Não               210             Sim   0.07
# 3          Sim                 Sim               167             Sim   0.49
# 4          Não                 Sim               156             Não   0.07
# 5          Não                 Sim               125             Não   0.07
# 6          Sim                 Não               168             Não   0.07
# 7          Sim                 Sim               172             Não   0.07

# %%
Dor no Peito
Sim-Sim -> 3 acertos e 2 erros
Não-Não -> 2 acertos e 1 erro

Artérias bloqueadas
Sim-Sim -> 3 acertos e 3 erros
Não-Não -> 1 acerto e 1 erro

Peso 
>176 Sim 3 acertos e 1 erro
<=176 Não 4 acertos

# %%
df = pd.concat([df, df_pesos], axis = 1)

# %%
df#[['Dor no peito','Artérias bloqueadas','Peso do paciente','Doença cardiaca']]

# %%
import math
x = []
y = []
for i in range(1,100):
    x_temp = i/100
    x.append(x_temp)
    y.append(math.log((1-x_temp)/x_temp)/2)
import matplotlib.pyplot as plt
plt.scatter(x,y)

# %%
0.125*math.exp(0.97)
# Out:
# 0.32974305741926907

# %%
import math
x = []
y = []
for i in range(1,350):
    x_temp = i/100
    x.append(x_temp)
    y.append(math.exp(-x_temp))
import matplotlib.pyplot as plt
plt.scatter(x,y)
#

# %%
0.125*math.exp(-0.97)
# Out:
# 0.047385379762924854

# %%
y
# Out:
# [1.010050167084168,
#  1.0202013400267558,
#  1.030454533953517,
#  1.0408107741923882,
#  1.0512710963760241,
#  1.0618365465453596,
#  1.0725081812542165,
#  1.0832870676749586,
#  1.0941742837052104,
#  1.1051709180756477,
#  1.1162780704588713,
#  1.1274968515793757,
#  1.1388283833246218,
#  1.1502737988572274,
#  1.161834242728283,
#  1.1735108709918103,
#  1.1853048513203654,
#  1.1972173631218102,
#  1.2092495976572515,
#  1.2214027581601699,
#  1.2336780599567432,
#  1.2460767305873808,
#  1.2586000099294778,
#  1.2712491503214047,
#  1.2840254166877414,
#  1.2969300866657718,
#  1.3099644507332473,
#  1.3231298123374369,
#  1.336427488025472,
#  1.3498588075760032,
#  1.3634251141321778,
#  1.3771277643359572,
#  1.3909681284637803,
#  1.4049475905635938,
#  1.4190675485932571,
#  1.4333294145603401,
#  1.4477346146633245,
#  1.4622845894342245,
#  1.4769807938826427,
#  1.4918246976412703,
#  1.5068177851128535,
#  1.5219615556186337,
#  1.5372575235482815,
# ...
