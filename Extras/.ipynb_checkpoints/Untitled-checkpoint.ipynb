# %%
import pandas as pd

# %%
married = pd.read_csv('married_first_sight.csv')

# %%
pd.crosstab(married['Location'], married['Name'])
# Out:
# Name                                   AJ Vollmoeller  Amber Bowles  \
# Location
# Atlanta, Georgia                                    0             0
# Boston, Massachusetts                               0             0
# Charlotte, North Carolina                           0             1
# Chicago, Illinois                                   0             0
# Dallas, Texas                                       0             0
# New York City and Northern New Jersey               0             0
# Philadelphia, Pennsylvania                          1             0
# South Florida                                       0             0
# Washington D.C.                                     0             0
#
# Name                                   Amber Martorana  Anthony D'Amico  \
# Location
# Atlanta, Georgia                                     0                0
# Boston, Massachusetts                                0                0
# ...
