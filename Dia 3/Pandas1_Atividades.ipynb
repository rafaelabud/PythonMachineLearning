# %% [markdown]
# <h3> Resolução Atividade 1 </h3>

# %% [markdown]
# ----------------------------------

# %%
#Importação das bibliotecas necessárias
import pandas as pd

# %%
#Abrindo o arquivo
df = pd.read_csv('world_happiness_report_2015.csv')

# %%
#Verificando o inicio do df
df.head()
# Out:
#        country          region  happiness rank  happiness score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    standard error  economy (GDP per Capita)   family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    health (Life Expectancy)  freedom  trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
#Verificando o final do df
df.tail()
# Out:
#      country                           region  happiness rank  \
# 159   Rwanda               Sub-Saharan Africa             154
# 160    Benin               Sub-Saharan Africa             155
# 161    Syria  Middle East and Northern Africa             156
# 162  Burundi               Sub-Saharan Africa             157
# 163     Togo               Sub-Saharan Africa             158
#
#      happiness score  standard error  economy (GDP per Capita)   family  \
# 159            3.465         0.03464                   0.22208  0.77370
# 160            3.340             NaN                   0.28665  0.35386
# 161            3.006         0.05015                   0.66320  0.47489
# 162            2.905         0.08658                   0.01530  0.41587
# 163            2.839         0.06727                   0.20868  0.13995
#
#      health (Life Expectancy)  freedom  trust (Government Corruption)  \
# 159                   0.42864  0.59201                        0.55191
# ...

# %%
#Verificando colunas
df.columns
# Out:
# Index(['country', 'region', 'happiness rank', 'happiness score',
#        'standard error', 'economy (GDP per Capita)', 'family',
#        'health (Life Expectancy)', 'freedom', 'trust (Government Corruption)',
#        'generosity', 'dystopia residual'],
#       dtype='object')

# %%
#Verificando os tipos de dados
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 164 entries, 0 to 163
# Data columns (total 12 columns):
# country                          164 non-null object
# region                           164 non-null object
# happiness rank                   164 non-null int64
# happiness score                  156 non-null float64
# standard error                   163 non-null float64
# economy (GDP per Capita)         164 non-null float64
# family                           164 non-null float64
# health (Life Expectancy)         164 non-null float64
# freedom                          164 non-null float64
# trust (Government Corruption)    164 non-null float64
# generosity                       164 non-null float64
# dystopia residual                150 non-null float64
# dtypes: float64(9), int64(1), object(2)
# memory usage: 15.5+ KB

# %%
#Renomeando colunas
df.rename(columns={'happiness rank':'rank_felicidade','happiness score':'score_felicidade','standard error':'stand_error',
                      'economy (GDP per Capita)':'PIB','health (Life Expectancy)':'expect_vida',
                      'trust (Government Corruption)':'corrupcao'}, inplace=True)

# %%
#Valores médios e mediano de expect_vida
df["expect_vida"]#.mean()
# Out:
# 0.6381872560975613

# %%
df["expect_vida"].median()
# Out:
# 0.70593

# %%
#Máximo do PIB
df["PIB"].max()
# Out:
# 1.69042

# %%
#Ou através do describe
df_describe = df.describe()
df_describe['health (Life Expectancy)']['mean']
# Out:
# 0.6381872560975613

# %%
#Criando uma Series de altura
altura = pd.Series([1.50,1.66,1.70,1.70,1.82], index=['Paty','Mari','Nat','Rafa','Math'])

# %%
altura
# Out:
# Paty    1.50
# Mari    1.66
# Nat     1.70
# Rafa    1.70
# Math    1.82
# dtype: float64

# %% [markdown]
# ----------------------------------
# <h3> Resolução Atividade 2 </h3>

# %%
#Selecionando os dados com o loc
df.loc[:,['country', 'region', 'family', 'freedom']].head()
# Out:
#        country          region   family  freedom
# 0  Switzerland  Western Europe  1.34951  0.66557
# 1      Iceland  Western Europe  1.40223  0.62877
# 2      Denmark  Western Europe  1.36058  0.64938
# 3       Norway  Western Europe  1.33095  0.66973
# 4       Canada   North America  1.32261  0.63297

# %%
#Selecionando os dados com o iloc
df.iloc[:,[0,1,6,8]].head()
# Out:
#        country          region   family  freedom
# 0  Switzerland  Western Europe  1.34951  0.66557
# 1      Iceland  Western Europe  1.40223  0.62877
# 2      Denmark  Western Europe  1.36058  0.64938
# 3       Norway  Western Europe  1.33095  0.66973
# 4       Canada   North America  1.32261  0.63297

# %%
#Selecionando as 15 primeiras linhas de country e PIB com o loc
df.loc[:15,['country', 'PIB']]
# Out:
#         country      PIB
# 0   Switzerland  1.39651
# 1       Iceland  1.30232
# 2       Denmark  1.32548
# 3        Norway  1.45900
# 4        Canada  1.32629
# 5       Finland  1.29025
# 6   Netherlands  1.32944
# 7        Sweden  1.33171
# 8   New Zealand  1.25018
# 9     Australia  1.33358
# 10       Israel  1.22857
# 11       Canada  1.32629
# 12      Finland  1.29025
# 13  Netherlands  1.32944
# 14       Sweden  1.33171
# 15   Costa Rica  0.95578

# %%
#Selecionando as 15 primeiras linhas de country e PIB com o iloc
df.iloc[:15,[0,5]]
# Out:
#         country      PIB
# 0   Switzerland  1.39651
# 1       Iceland  1.30232
# 2       Denmark  1.32548
# 3        Norway  1.45900
# 4        Canada  1.32629
# 5       Finland  1.29025
# 6   Netherlands  1.32944
# 7        Sweden  1.33171
# 8   New Zealand  1.25018
# 9     Australia  1.33358
# 10       Israel  1.22857
# 11       Canada  1.32629
# 12      Finland  1.29025
# 13  Netherlands  1.32944
# 14       Sweden  1.33171

# %%
#Selecionando os dados de score_felicidade maiores que 5
df_hap = df.loc[df.score_felicidade > 5]

# %%
df_hap
# Out:
#               country                           region  rank_felicidade  \
# 0         Switzerland                   Western Europe                1
# 1             Iceland                   Western Europe                2
# 2             Denmark                   Western Europe                3
# 3              Norway                   Western Europe                4
# 4              Canada                    North America                5
# ..                ...                              ...              ...
# 94             Latvia       Central and Eastern Europe               89
# 95        Philippines                Southeastern Asia               90
# 96  Somaliland region               Sub-Saharan Africa               91
# 97            Morocco  Middle East and Northern Africa               92
# 98          Macedonia       Central and Eastern Europe               93
#
#     score_felicidade  stand_error      PIB   family  expect_vida  freedom  \
# ...

# %%
#Selecionando dados da Southern Asia
df_asia = df.loc[df.region == 'Southern Asia']

# %%
df_asia
# Out:
#          country         region  rank_felicidade  score_felicidade  \
# 84        Bhutan  Southern Asia               79             5.253
# 86      Pakistan  Southern Asia               81             5.194
# 114   Bangladesh  Southern Asia              109             4.694
# 122        India  Southern Asia              117             4.565
# 126        Nepal  Southern Asia              121             4.514
# 137    Sri Lanka  Southern Asia              132             4.271
# 158  Afghanistan  Southern Asia              153             3.575
#
#      stand_error      PIB   family  expect_vida  freedom  corrupcao  \
# 84       0.03225  0.77042  1.10395      0.57407  0.53206    0.15445
# 86       0.03726  0.59543  0.41411      0.51466  0.12102    0.10464
# 114      0.03077  0.39753  0.43106      0.60164  0.40820    0.12569
# 122      0.02043  0.64499  0.38174      0.51529  0.39786    0.08492
# 126      0.03607  0.35997  0.86449      0.56874  0.38282    0.05907
# ...
